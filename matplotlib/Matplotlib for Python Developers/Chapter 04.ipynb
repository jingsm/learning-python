# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %%
x = np.arange(0, 10, 0.1)
y = np.random.randn(len(x))
plt.plot(x, y)
plt.title('random numbers')
plt.show('7900_04_01.png')

# %%
fig = plt.figure() 
ax1 = fig.add_subplot(211) 
ax1.plot([1,2,3], [1,2,3]) 
ax2 = fig.add_subplot(212) 
ax2.plot([1,2,3], [3,2,1]) 
plt.show('7900_04_02.png')

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot([1,2,3], [1,2,3])
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot([1,2,3], [3,2,1])
fig1.savefig('7900_04_03.png')
fig2.show('7900_04_04.png')
# Out:
# c:\programs\python35\lib\site-packages\matplotlib\figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
x = np.arange(0., np.e, 0.01)
y1 = np.exp(-x)
y2 = np.log(x)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, y1)
ax1.set_ylabel('Y values for exp(-x)')
ax2 = ax1.twinx()
ax2.plot(x, y2, 'r')
ax2.set_xlim([0,np.e])
ax2.set_ylabel('Y values for ln(x)')
ax2.set_xlabel('Same X for both exp(-x) and ln(x)')
plt.show('7900_04_05.png')
# Out:
# c:\programs\python35\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
mpl.rcParams['font.size'] = 4.
x = np.arange(0., 20, 0.01)
fig = plt.figure()
ax1 = fig.add_subplot(311)
y1 = np.exp(x/6.)
ax1.plot(x, y1)
ax1.grid(True)
ax1.set_yscale('log')
ax1.set_ylabel('log Y')
ax2 = fig.add_subplot(312)
y2 = np.cos(np.pi*x)
ax2.semilogx(x, y2)
ax2.set_xlim([0,20])
ax2.grid(True)
ax2.set_ylabel('log X')
ax3 = fig.add_subplot(313)
y3 = np.exp(x/4.)
ax3.loglog(x, y3, basex=3)
ax3.grid(True)
ax3.set_ylabel('log X and Y')
plt.show('7900_04_06.png')

# %%
mpl.rcParams['font.size'] = 7.
x = np.arange(11)
fig = plt.figure()
ax1 = fig.add_subplot(311)
ax1.plot(x, x)
ax2 = fig.add_subplot(312, sharex=ax1)
ax2.plot(2*x, 2*x)
ax3 = fig.add_subplot(313, sharex=ax1)
ax3.plot(3*x, 3*x)
plt.show('7900_04_07.png')

# %%
dates = [dt.datetime.today() + dt.timedelta(days=i) for i in range(10)] 
values = np.random.rand(len(dates))
plt.plot_date(mpl.dates.date2num(dates), values, linestyle='-')
plt.show('7900_04_08.png')

# %%
fig = plt.figure()
ax2 = fig.add_subplot(212)
date2_1 = dt.datetime(2008, 9, 23)
date2_2 = dt.datetime(2008, 10, 3)
delta2 = dt.timedelta(days=1)
dates2 = mpl.dates.drange(date2_1, date2_2, delta2)
y2 = np.random.rand(len(dates2))
ax2.plot_date(dates2, y2, linestyle='-')
dateFmt = mpl.dates.DateFormatter('%Y-%m-%d')
ax2.xaxis.set_major_formatter(dateFmt)
daysLoc = mpl.dates.DayLocator()
hoursLoc = mpl.dates.HourLocator(interval=6)
ax2.xaxis.set_major_locator(daysLoc)
ax2.xaxis.set_minor_locator(hoursLoc)
fig.autofmt_xdate(bottom=0.18)
fig.subplots_adjust(left=0.18)
ax1 = fig.add_subplot(211)
date1_1 = dt.datetime(2008, 9, 23)
date1_2 = dt.datetime(2009, 2, 16)
delta1 = dt.timedelta(days=10)
dates1 = mpl.dates.drange(date1_1, date1_2, delta1)
y1 = np.random.rand(len(dates1))
ax1.plot_date(dates1, y1, linestyle='-')
monthsLoc = mpl.dates.MonthLocator()
weeksLoc = mpl.dates.WeekdayLocator()
ax1.xaxis.set_major_locator(monthsLoc)
ax1.xaxis.set_minor_locator(weeksLoc)
monthsFmt = mpl.dates.DateFormatter('%b')
ax1.xaxis.set_major_formatter(monthsFmt)
plt.show('7900_04_09.png')

# %%
fig = plt.figure()
ax= fig.add_subplot(111)
ax.set_xlim([1,6])
ax.set_ylim([1,9])
ax.text(2, 8, r"$ \mu \alpha \tau \pi \lambda \omega \tau \lambda \iota \beta $")
ax.text(2, 6, r"$ \lim_{x \rightarrow 0} \frac{1}{x} $")
ax.text(2, 4, r"$ a \ \leq \ b \ \leq \ c \ \Rightarrow \ a \ \leq \ c$")
ax.text(2, 2, r"$ \sum_{i=1}^{\infty}\ x_i^2$")
ax.text(4, 8, r"$ \sin(0) = \cos(\frac{\pi}{2})$")
ax.text(4, 6, r"$ \sqrt[3]{x} = \sqrt{y}$")
ax.text(4, 4, r"$ \neg (a \wedge b) \Leftrightarrow \neg a \vee \neg b$")
ax.text(4, 2, r"$ \int_a^b f(x)dx$")
plt.show('7900_04_10.png')

# %%
mpl.rcParams['text.usetex'] = True
fig = plt.figure()
ax= fig.add_subplot(111)
ax.set_xlim([1,6])
ax.set_ylim([1,9])
ax.text(2, 8, r"$ \mu \alpha \tau \pi \lambda \omega \tau \lambda \iota \beta $")
ax.text(2, 6, r"$ \lim_{x \rightarrow 0} \frac{1}{x} $")
ax.text(2, 4, r"$ a \leq b \leq c \Rightarrow a \leq c$")
ax.text(2, 2, r"$ \sum_{i=1}^{\infty}\ x_i^2$")
ax.text(4, 8, r"$ \sin(0) = \cos(\frac{\pi}{2})$")
ax.text(4, 6, r"$ \sqrt[3]{x} = \sqrt{y}$")
ax.text(4, 4, r"$ \neg (a \wedge b) \Leftrightarrow \neg a \vee \neg b$")
ax.text(4, 2, r"$ \int_a^b f(x)dx$")
plt.show('7900_04_11.png')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\programs\python35\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     303                 pass
#     304             else:
# --> 305                 return printer(obj)
#     306             # Finally look for special method names
#     307             method = get_real_method(obj, self.print_method)
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     237
#     238     if 'png' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     240     if 'retina' in formats or 'png2x' in formats:
#     241         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     121
#     122     bytes_io = BytesIO()
# --> 123     fig.canvas.print_figure(bytes_io, **kw)
#     124     data = bytes_io.getvalue()
#     125     if fmt == 'svg':
#
# c:\programs\python35\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1076         for tick in ticks:
#    1077             if tick.label1On and tick.label1.get_visible():
# -> 1078                 extent = tick.label1.get_window_extent(renderer)
#    1079                 ticklabelBoxes.append(extent)
#    1080             if tick.label2On and tick.label2.get_visible():
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     965             raise RuntimeError('Cannot get window extent w/o renderer')
#     966
# --> 967         bbox, info, descent = self._get_layout(self._renderer)
#     968         x, y = self.get_unitless_position()
#     969         x, y = self.get_transform().transform_point((x, y))
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     351         tmp, lp_h, lp_bl = renderer.get_text_width_height_descent('lp',
#     352                                                          self._fontproperties,
# --> 353                                                          ismath=False)
#     354         offsety = (lp_h - lp_bl) * self._linespacing
#     355
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     228             fontsize = prop.get_size_in_points()
#     229             w, h, d = texmanager.get_text_width_height_descent(s, fontsize,
# --> 230                                                                renderer=self)
#     231             return w, h, d
#     232
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     674         else:
#     675             # use dviread. It sometimes returns a wrong descent.
# --> 676             dvifile = self.make_dvi(tex, fontsize)
#     677             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     678             try:
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     421                      'string:\n%s\nHere is the full report generated by '
#     422                      'LaTeX: \n\n' % repr(tex.encode('unicode_escape')) +
# --> 423                      report))
#     424             else:
#     425                 mpl.verbose.report(report, 'debug')
#
# RuntimeError: LaTeX was not able to process the following string:
# b'lp'
# Here is the full report generated by LaTeX:

# %%
mpl.rcParams['text.usetex'] = True
x = np.arange(0.,5., .01)
y = [np.sin(2*np.pi*xx) * np.exp(-xx) for xx in x]
plt.plot(x, y, label=r'$\sin(2\pi x)\exp(-x)$')
plt.plot(x, np.exp(-x), label=r'$\exp(-x)$')
plt.plot(x, -np.exp(-x), label=r'$-\exp(-x)$')
plt.title(r'$\sin(2\pi x)\exp(-x)$ with the two asymptotes $\pm\exp(-x)$')
plt.legend()
plt.show('7900_04_12.png')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\programs\python35\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     303                 pass
#     304             else:
# --> 305                 return printer(obj)
#     306             # Finally look for special method names
#     307             method = get_real_method(obj, self.print_method)
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     237
#     238     if 'png' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     240     if 'retina' in formats or 'png2x' in formats:
#     241         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     121
#     122     bytes_io = BytesIO()
# --> 123     fig.canvas.print_figure(bytes_io, **kw)
#     124     data = bytes_io.getvalue()
#     125     if fmt == 'svg':
#
# c:\programs\python35\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1076         for tick in ticks:
#    1077             if tick.label1On and tick.label1.get_visible():
# -> 1078                 extent = tick.label1.get_window_extent(renderer)
#    1079                 ticklabelBoxes.append(extent)
#    1080             if tick.label2On and tick.label2.get_visible():
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     965             raise RuntimeError('Cannot get window extent w/o renderer')
#     966
# --> 967         bbox, info, descent = self._get_layout(self._renderer)
#     968         x, y = self.get_unitless_position()
#     969         x, y = self.get_transform().transform_point((x, y))
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     351         tmp, lp_h, lp_bl = renderer.get_text_width_height_descent('lp',
#     352                                                          self._fontproperties,
# --> 353                                                          ismath=False)
#     354         offsety = (lp_h - lp_bl) * self._linespacing
#     355
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     228             fontsize = prop.get_size_in_points()
#     229             w, h, d = texmanager.get_text_width_height_descent(s, fontsize,
# --> 230                                                                renderer=self)
#     231             return w, h, d
#     232
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     674         else:
#     675             # use dviread. It sometimes returns a wrong descent.
# --> 676             dvifile = self.make_dvi(tex, fontsize)
#     677             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     678             try:
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     421                      'string:\n%s\nHere is the full report generated by '
#     422                      'LaTeX: \n\n' % repr(tex.encode('unicode_escape')) +
# --> 423                      report))
#     424             else:
#     425                 mpl.verbose.report(report, 'debug')
#
# RuntimeError: LaTeX was not able to process the following string:
# b'lp'
# Here is the full report generated by LaTeX:

# %%
matr = np.random.rand(21,31)
cs = plt.contour(matr)
plt.savefig('7900_04_13.png')
csf = plt.contourf(matr)
plt.colorbar()
plt.show('7900_04_14.png')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-078b86bcd3f9> in <module>()
#       1 matr = np.random.rand(21,31)
#       2 cs = plt.contour(matr)
# ----> 3 plt.savefig('7900_04_13.png')
#       4 csf = plt.contourf(matr)
#       5 plt.colorbar()
#
# c:\programs\python35\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# c:\programs\python35\lib\site-packages\matplotlib\figure.py in savefig(self, *args, **kwargs)
#    1570             self.set_frameon(frameon)
#    1571
# -> 1572         self.canvas.print_figure(*args, **kwargs)
#    1573
#    1574         if frameon:
#
# c:\programs\python35\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2242                 orientation=orientation,
#    2243                 bbox_inches_restore=_bbox_inches_restore,
# -> 2244                 **kwargs)
#    2245         finally:
#    2246             if bbox_inches and restore_bbox:
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1076         for tick in ticks:
#    1077             if tick.label1On and tick.label1.get_visible():
# -> 1078                 extent = tick.label1.get_window_extent(renderer)
#    1079                 ticklabelBoxes.append(extent)
#    1080             if tick.label2On and tick.label2.get_visible():
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     965             raise RuntimeError('Cannot get window extent w/o renderer')
#     966
# --> 967         bbox, info, descent = self._get_layout(self._renderer)
#     968         x, y = self.get_unitless_position()
#     969         x, y = self.get_transform().transform_point((x, y))
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     351         tmp, lp_h, lp_bl = renderer.get_text_width_height_descent('lp',
#     352                                                          self._fontproperties,
# --> 353                                                          ismath=False)
#     354         offsety = (lp_h - lp_bl) * self._linespacing
#     355
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     228             fontsize = prop.get_size_in_points()
#     229             w, h, d = texmanager.get_text_width_height_descent(s, fontsize,
# --> 230                                                                renderer=self)
#     231             return w, h, d
#     232
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     674         else:
#     675             # use dviread. It sometimes returns a wrong descent.
# --> 676             dvifile = self.make_dvi(tex, fontsize)
#     677             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     678             try:
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     421                      'string:\n%s\nHere is the full report generated by '
#     422                      'LaTeX: \n\n' % repr(tex.encode('unicode_escape')) +
# --> 423                      report))
#     424             else:
#     425                 mpl.verbose.report(report, 'debug')
#
# RuntimeError: LaTeX was not able to process the following string:
# b'lp'
# Here is the full report generated by LaTeX:

# %%
x = np.arange(-2,2,0.01)
y = np.arange(-2,2,0.01)
X, Y = np.meshgrid(x,y) 
ellipses = X*X/9 + Y*Y/4 -1
cs = plt.contour(ellipses)
plt.clabel(cs)
plt.show('7900_04_15.png')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-a260c172dfd4> in <module>()
#       4 ellipses = X*X/9 + Y*Y/4 -1
#       5 cs = plt.contour(ellipses)
# ----> 6 plt.clabel(cs)
#       7 plt.show('7900_04_15.png')
#
# c:\programs\python35\lib\site-packages\matplotlib\pyplot.py in clabel(CS, *args, **kwargs)
#    2831                       mplDeprecation)
#    2832     try:
# -> 2833         ret = ax.clabel(CS, *args, **kwargs)
#    2834     finally:
#    2835         ax._hold = washold
#
# c:\programs\python35\lib\site-packages\matplotlib\axes\_axes.py in clabel(self, CS, *args, **kwargs)
#    5833
#    5834     def clabel(self, CS, *args, **kwargs):
# -> 5835         return CS.clabel(*args, **kwargs)
#    5836     clabel.__doc__ = mcontour.ContourSet.clabel.__doc__
#    5837
#
# c:\programs\python35\lib\site-packages\matplotlib\contour.py in clabel(self, *args, **kwargs)
#     212             blocking_contour_labeler(inline, inline_spacing)
#     213         else:
# --> 214             self.labels(inline, inline_spacing)
#     215
#     216         # Hold on to some old attribute names.  These are deprecated and will
#
# c:\programs\python35\lib\site-packages\matplotlib\contour.py in labels(self, inline, inline_spacing)
#     640             con = self.collections[icon]
#     641             trans = con.get_transform()
# --> 642             lw = self.get_label_width(lev, self.labelFmt, fsize)
#     643             lw *= self.ax.figure.dpi / 72.0  # scale to screen coordinates
#     644             additions = []
#
# c:\programs\python35\lib\site-packages\matplotlib\contour.py in get_label_width(self, lev, fmt, fsize)
#     285                 self._TeX_manager = texmanager.TexManager()
#     286             lw, _, _ = self._TeX_manager.get_text_width_height_descent(lev,
# --> 287                                                                        fsize)
#     288         elif ismath:
#     289             if not hasattr(self, '_mathtext_parser'):
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     674         else:
#     675             # use dviread. It sometimes returns a wrong descent.
# --> 676             dvifile = self.make_dvi(tex, fontsize)
#     677             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     678             try:
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     421                      'string:\n%s\nHere is the full report generated by '
#     422                      'LaTeX: \n\n' % repr(tex.encode('unicode_escape')) +
# --> 423                      report))
#     424             else:
#     425                 mpl.verbose.report(report, 'debug')
#
# RuntimeError: LaTeX was not able to process the following string:
# b'-0.800'
# Here is the full report generated by LaTeX:

# %%
x = np.arange(-2,2,0.01)
y = np.arange(-2,2,0.01)
X, Y = np.meshgrid(x,y) 
ellipses = X*X/9 + Y*Y/4 -1
plt.imshow(ellipses)
plt.colorbar()
plt.show('7900_04_16.png')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\programs\python35\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     303                 pass
#     304             else:
# --> 305                 return printer(obj)
#     306             # Finally look for special method names
#     307             method = get_real_method(obj, self.print_method)
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     237
#     238     if 'png' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     240     if 'retina' in formats or 'png2x' in formats:
#     241         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     121
#     122     bytes_io = BytesIO()
# --> 123     fig.canvas.print_figure(bytes_io, **kw)
#     124     data = bytes_io.getvalue()
#     125     if fmt == 'svg':
#
# c:\programs\python35\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1076         for tick in ticks:
#    1077             if tick.label1On and tick.label1.get_visible():
# -> 1078                 extent = tick.label1.get_window_extent(renderer)
#    1079                 ticklabelBoxes.append(extent)
#    1080             if tick.label2On and tick.label2.get_visible():
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     965             raise RuntimeError('Cannot get window extent w/o renderer')
#     966
# --> 967         bbox, info, descent = self._get_layout(self._renderer)
#     968         x, y = self.get_unitless_position()
#     969         x, y = self.get_transform().transform_point((x, y))
#
# c:\programs\python35\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     351         tmp, lp_h, lp_bl = renderer.get_text_width_height_descent('lp',
#     352                                                          self._fontproperties,
# --> 353                                                          ismath=False)
#     354         offsety = (lp_h - lp_bl) * self._linespacing
#     355
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     228             fontsize = prop.get_size_in_points()
#     229             w, h, d = texmanager.get_text_width_height_descent(s, fontsize,
# --> 230                                                                renderer=self)
#     231             return w, h, d
#     232
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     674         else:
#     675             # use dviread. It sometimes returns a wrong descent.
# --> 676             dvifile = self.make_dvi(tex, fontsize)
#     677             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     678             try:
#
# c:\programs\python35\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     421                      'string:\n%s\nHere is the full report generated by '
#     422                      'LaTeX: \n\n' % repr(tex.encode('unicode_escape')) +
# --> 423                      report))
#     424             else:
#     425                 mpl.verbose.report(report, 'debug')
#
# RuntimeError: LaTeX was not able to process the following string:
# b'lp'
# Here is the full report generated by LaTeX:
