# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.arange(1,3)
plt.plot(y, 'y')
plt.plot(y+1, 'm')
plt.plot(y+2, 'c')
plt.show()

# %%
y = np.arange(1,3)
plt.plot(y, '--', y+1, '-.', y+2, ':')
plt.show()

# %%
y = np.arange(1,3,0.2)
plt.plot(y, 'x', y+0.5, 'o', y+1, 'D', y+1.5, '^', y+2, 's')
plt.show()

# %%
y = np.arange(1,3,0.3)
plt.plot(y, 'cx--', y+1, 'mo:', y+2, 'kp-.')
plt.show()

# %%
y = np.arange(1,3,0.3)
plt.plot(y, color='blue', linestyle='dashdot', linewidth=4,
         marker='o', markerfacecolor='red', markeredgecolor='black',
         markeredgewidth=3, markersize=12)
plt.show()

# %%
x=[5, 3, 7, 2, 4, 1]
plt.plot(x)
plt.xticks(range(len(x)), ['a', 'b', 'c', 'd', 'e', 'f'])
plt.yticks(range(1, 8, 2))
plt.show()

# %%
y = np.random.randn(1000)

plt.hist(y)
plt.savefig('7900_03_07.png')

plt.clf()
plt.hist(y, 25)
plt.show()

# %%
x = np.arange(0, 4, 0.2)
y = np.exp(-x)
e1 = 0.1 * np.abs(np.random.randn(len(y)))
plt.errorbar(x, y, yerr=e1, fmt='.-')
plt.savefig('7900_03_09.png')
plt.clf()
e2 = 0.1 * np.abs(np.random.randn(len(y)))
plt.errorbar(x, y, yerr=e1, xerr=e2, fmt='.-', capsize=0)
plt.savefig('7900_03_10.png')
plt.clf()
plt.errorbar(x, y, yerr=[e1,e2], fmt='.-')
plt.show()

# %%
plt.bar([1,2,3], [3,2,5])
plt.show()

# %%
dict = {'A': 40, 'B': 70, 'C': 30, 'D': 85}
for i, key in enumerate(dict):
    plt.bar(i, dict[key])
plt.xticks(np.arange(len(dict))+0.4, dict.keys())
plt.yticks(dict.values())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\programs\python35\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     303                 pass
#     304             else:
# --> 305                 return printer(obj)
#     306             # Finally look for special method names
#     307             method = get_real_method(obj, self.print_method)
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     237
#     238     if 'png' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     240     if 'retina' in formats or 'png2x' in formats:
#     241         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\programs\python35\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     121
#     122     bytes_io = BytesIO()
# --> 123     fig.canvas.print_figure(bytes_io, **kw)
#     124     data = bytes_io.getvalue()
#     125     if fmt == 'svg':
#
# c:\programs\python35\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# c:\programs\python35\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# c:\programs\python35\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# c:\programs\python35\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in _update_ticks(self, renderer)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# c:\programs\python35\lib\site-packages\matplotlib\axis.py in iter_ticks(self)
#     911         """
#     912         majorLocs = self.major.locator()
# --> 913         majorTicks = self.get_major_ticks(len(majorLocs))
#     914         self.major.formatter.set_locs(majorLocs)
#     915         majorLabels = [self.major.formatter(val, i)
#
# TypeError: len() of unsized object

# %%
data1=10*np.random.rand(5)
data2=10*np.random.rand(5)
data3=10*np.random.rand(5)
e2 = 0.5 * np.abs(np.random.randn(len(data2)))
locs = np.arange(1, len(data1)+1)
width = 0.27
plt.bar(locs, data1, width=width)
plt.bar(locs+width, data2, yerr=e2, width=width, color='red')
plt.bar(locs+2*width, data3, width=width, color='green')
plt.xticks(locs + width*1.5, locs)
#plt.show()
plt.show()

# %%
plt.figure(figsize=(3,3))
x = [45, 35, 20]
labels  = ['Cats', 'Dogs', 'Fishes']
plt.pie(x, labels = labels)
plt.show()

# %%
plt.figure(figsize=(3,3))
x = [4, 9, 21, 55, 30, 18]
labels = ['Swiss', 'Austria', 'Spain', 'Italy', 'France', 'Benelux']
explode = [0.2, 0.1, 0, 0, 0.1, 0]
plt.pie(x, labels = labels, explode = explode, autopct = '%1.1f%%');
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y)
plt.savefig('7900_03_17.png')
size = 50*np.random.randn(1000)
colors = np.random.rand(1000)
plt.scatter(x,y, s=size, c=colors)
plt.show()
# Out:
# c:\programs\python35\lib\site-packages\matplotlib\collections.py:865: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
theta = np.arange(0., 2., 1./180.)*np.pi

plt.polar(3*theta, theta/5);
plt.polar(theta, np.cos(4*theta));
plt.polar(theta, [1.4]*len(theta));

plt.show()

# %%
theta = np.arange(0., 2., 1./180.)*np.pi
r = np.abs(np.sin(5*theta)-2.*np.cos(theta))
plt.polar(theta, r)
plt.thetagrids(range(45, 360, 90))
plt.rgrids(np.arange(0.2, 3.1, .7), angle=0)
plt.show()

# %%
x = np.arange(0, 2*np.pi, .01)
y = np.sin(x)
plt.plot(x, y)
plt.text(0.1, -0.04, 'sin(0)=0')
plt.show()

# %%
y = [13, 11, 13, 12, 13, 10, 30, 12, 11, 13, 12, 12, 12, 11, 12]
plt.plot(y)
plt.ylim(ymax=35)
plt.annotate('this spot must really\nmean something', xy=(6, 30), xytext=(8, 31.5), arrowprops=dict(facecolor='black', shrink=0.05))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4d333f7d3e1a> in <module>()
#       2 plt.plot(y)
#       3 plt.ylim(ymax=35)
# ----> 4 plt.annotate('this spot must really\nmean something', xy=(6, 30), xytext=(8, 31.5), arrowprops=dict(facecolor='black', shrink=0.05))
#       5 plt.show()
#
# TypeError: 'dict' object is not callable

# %%
plt.axis([0, 9, 0, 18])
arrstyles = ['-', '->', '-[', '<-', '<->', 'fancy', 'simple', 'wedge']
for i, style in enumerate(arrstyles):
    plt.annotate(style, xytext=(1, 2+2*i), xy=(4, 1+2*i),arrowprops=dict(arrowstyle=style))
connstyles=["arc", "arc,angleA=10,armA=30,rad=15", "arc3,rad=.2", "arc3,rad=-.2", "angle", "angle3"]
for i, style in enumerate(connstyles):
    plt.annotate("", xytext=(6, 4+2*i), xy=(8, 3+2*i), arrowprops=dict(arrowstyle='->', connectionstyle=style))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-8425c3fbb07d> in <module>()
#       2 arrstyles = ['-', '->', '-[', '<-', '<->', 'fancy', 'simple', 'wedge']
#       3 for i, style in enumerate(arrstyles):
# ----> 4     plt.annotate(style, xytext=(1, 2+2*i), xy=(4, 1+2*i),arrowprops=dict(arrowstyle=style))
#       5 connstyles=["arc", "arc,angleA=10,armA=30,rad=15", "arc3,rad=.2", "arc3,rad=-.2", "angle", "angle3"]
#       6 for i, style in enumerate(connstyles):
#
# TypeError: 'dict' object is not callable

# %%
y = [13, 11, 13, 12, 13, 10, 30, 12, 11, 13, 12, 12, 12, 11, 12]
plt.plot(y)
plt.ylim(ymax=35)
plt.annotate('this spot must really\nmean something', xy=(6, 30), xytext=(8, 31.5), arrowprops=dict(facecolor='black', shrink=0.05))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-4d333f7d3e1a> in <module>()
#       2 plt.plot(y)
#       3 plt.ylim(ymax=35)
# ----> 4 plt.annotate('this spot must really\nmean something', xy=(6, 30), xytext=(8, 31.5), arrowprops=dict(facecolor='black', shrink=0.05))
#       5 plt.show()
#
# TypeError: 'dict' object is not callable
